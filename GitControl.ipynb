# %% [markdown]
# <a href="https://colab.research.google.com/github/Abotyt/australianUnemployedPrediction/blob/main/GitControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone repository

# %%
# !git clone https://github.com/Abotyt/australianUnemployedPrediction.git
# Out:
# Cloning into 'australianUnemployedPrediction'...
# ...

# %% [markdown]
# Push the file to repository

# %%
repository_name = 'australianUnemployedPrediction'
email = 'yuchienabbott@gmail.com'
username = 'Abotyt'

# %%
# %cd {repository_name}
# !git config --global user.email {email}
# !git config --global user.name {username}
# Out:
# /content/australianUnemployedPrediction

# %%
# !git pull origin main # or the name of your default branch, e.g., master
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 887 bytes | 887.00 KiB/s, done.
# From https://github.com/Abotyt/australianUnemployedPrediction
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# !git add .
# Or to add a specific file:
# !git add <file_name>
