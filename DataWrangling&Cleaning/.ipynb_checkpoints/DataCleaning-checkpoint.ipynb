# %% [markdown]
# # Project: Australian Unemployed Prediction
# ### Description:

# %% [markdown]
# Goal: explore and clean the data
# Tech: Python\
# Library: panda
# Data Source: Australian Bureau of Statistics

# %% [markdown]
# Data:\
# All groups CPI, index numbers and percentage changes.xlsx

# %% [markdown]
# ### Library:

# %%
# install
# !pip install pandas openpyxl

# %%
import pandas as pd

# %% [markdown]
# ### Files:

# %%
fileLocation = "D:\Working Station\Career & Project\Data\laber prediction\Original Data"
CPI_Monthlypath = fileLocation + "\\" + "CPI_MonthlyPercentageChange.xlsx"
EmployPopulationRatial_Path = fileLocation + "\\" + "EmploymentToPopulationRatio.csv"

# %% [markdown]
# Read files

# %%
CPI_MonthlyOriginal = pd.read_excel(CPI_Monthlypath, sheet_name = "Data1")
EmployPopulationRatial_Original = pd.read_csv(EmployPopulationRatial_Path)

# %% [markdown]
# ### CPI_MonthlyPath

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
CPI_MonthlyPath = CPI_MonthlyOriginal.copy()
CPI_MonthlyPath.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  All groups CPI ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Food and non-alcoholic beverages ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Bread and cereal products ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Bread ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Cakes and biscuits ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Breakfast cereals ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Other cereal products ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Meat and seafoods ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Beef and veal ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Education ;  Australia ;.1  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Preschool and primary education ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Secondary education ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Tertiary education ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Insurance and financial services ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Insurance ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Insurance ;  Australia ;.1  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Financial services ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Deposit and loan facilities (direct charges) ;  Australia ;  \
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
#   Contribution to All groups CPI Percentage Points Change from Previous Period ;  Other financial services ;  Australia ;
# 0                                              % pts
# 1                                           Original
# 2                                            DERIVED
# 3                                              Month
# 4                                                  1
#
# [5 rows x 133 columns]

# %% [markdown]
# Observation:\
# Data set type - structural data, wide data sets
# Size - 30rows X 133 columns
# columns- first column contains the information of each rows without a column name which suppose to be the column names, including but not limited to Unit, series type, data type, etc. From the seconde column to the last column, the column name contains the industry, including all groups, non-alcoholic beverages, bread and cereal product, etc.
# Data types - the data sets contain categorical, numerical and datetime datasets

# %% [markdown]
# #### Data processing plan

# %% [markdown]
# Step1 - transfer the wide data to long.\
# Step2 - extract the industries info and name the column industry.\
# Step3 - extract the Month and Year information from the datetime (located in the first row originally), named as Month and Year.\
# Step4 - deleted the columns/information that is not neceessary, for example colleciton month, series start, etc.\

# %% [markdown]
# #### Step1 - transfer the wide data to long.

# %%
CPT_Wide = CPI_MonthlyPath.T

# %% [markdown]
# #### Step2 - extract the industries info and name the column industry.

# %%
CPT_Wide.head()
# Out:
#                                                        0            1   \
# Unnamed: 0                                           Unit  Series Type
# Contribution to All groups CPI Percentage Point...  % pts     Original
# Contribution to All groups CPI Percentage Point...  % pts     Original
# Contribution to All groups CPI Percentage Point...  % pts     Original
# Contribution to All groups CPI Percentage Point...  % pts     Original
#
#                                                            2          3   \
# Unnamed: 0                                          Data Type  Frequency
# Contribution to All groups CPI Percentage Point...    DERIVED      Month
# Contribution to All groups CPI Percentage Point...    DERIVED      Month
# Contribution to All groups CPI Percentage Point...    DERIVED      Month
# Contribution to All groups CPI Percentage Point...    DERIVED      Month
#
#                                                                   4   \
# Unnamed: 0                                          Collection Month
# Contribution to All groups CPI Percentage Point...                 1
# Contribution to All groups CPI Percentage Point...                 1
# Contribution to All groups CPI Percentage Point...                 1
# Contribution to All groups CPI Percentage Point...                 1
#
#                                                                      5   \
# Unnamed: 0                                                 Series Start
# Contribution to All groups CPI Percentage Point...  2024-05-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2024-05-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2024-05-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2024-05-01 00:00:00
#
#                                                                      6   \
# Unnamed: 0                                                   Series End
# Contribution to All groups CPI Percentage Point...  2026-01-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2026-01-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2026-01-01 00:00:00
# Contribution to All groups CPI Percentage Point...  2026-01-01 00:00:00
#
#                                                          7            8   \
# Unnamed: 0                                          No. Obs    Series ID
# Contribution to All groups CPI Percentage Point...       21  A130393725R
# Contribution to All groups CPI Percentage Point...       21  A130395482V
# Contribution to All groups CPI Percentage Point...       21  A130391709C
# Contribution to All groups CPI Percentage Point...       21  A130393207R
#
#                                                                      9   ...  \
# Unnamed: 0                                          2024-05-01 00:00:00  ...
# Contribution to All groups CPI Percentage Point...              -0.2307  ...
# Contribution to All groups CPI Percentage Point...               0.0768  ...
# Contribution to All groups CPI Percentage Point...               0.0015  ...
# Contribution to All groups CPI Percentage Point...              -0.0013  ...
#
#                                                                      20  \
# Unnamed: 0                                          2025-04-01 00:00:00
# Contribution to All groups CPI Percentage Point...               0.7401
# Contribution to All groups CPI Percentage Point...               0.0676
# Contribution to All groups CPI Percentage Point...              -0.0059
# Contribution to All groups CPI Percentage Point...              -0.0018
#
#                                                                      21  \
# Unnamed: 0                                          2025-05-01 00:00:00
# Contribution to All groups CPI Percentage Point...               -0.493
# Contribution to All groups CPI Percentage Point...               0.0198
# Contribution to All groups CPI Percentage Point...              -0.0087
# Contribution to All groups CPI Percentage Point...              -0.0028
#
#                                                                      22  \
# Unnamed: 0                                          2025-06-01 00:00:00
# Contribution to All groups CPI Percentage Point...               0.1449
# Contribution to All groups CPI Percentage Point...               0.0756
# Contribution to All groups CPI Percentage Point...              -0.0022
# Contribution to All groups CPI Percentage Point...              -0.0021
#
#                                                                      23  \
# Unnamed: 0                                          2025-07-01 00:00:00
# Contribution to All groups CPI Percentage Point...                1.312
# Contribution to All groups CPI Percentage Point...                0.062
# Contribution to All groups CPI Percentage Point...               0.0109
# Contribution to All groups CPI Percentage Point...               0.0007
#
#                                                                      24  \
# Unnamed: 0                                          2025-08-01 00:00:00
# Contribution to All groups CPI Percentage Point...              -0.0755
# Contribution to All groups CPI Percentage Point...               0.0174
# Contribution to All groups CPI Percentage Point...               0.0007
# Contribution to All groups CPI Percentage Point...              -0.0003
#
#                                                                      25  \
# Unnamed: 0                                          2025-09-01 00:00:00
# Contribution to All groups CPI Percentage Point...               0.4484
# Contribution to All groups CPI Percentage Point...              -0.0456
# Contribution to All groups CPI Percentage Point...              -0.0041
# Contribution to All groups CPI Percentage Point...              -0.0005
#
#                                                                      26  \
# Unnamed: 0                                          2025-10-01 00:00:00
# Contribution to All groups CPI Percentage Point...              -0.0074
# Contribution to All groups CPI Percentage Point...               0.0258
# Contribution to All groups CPI Percentage Point...               0.0013
# Contribution to All groups CPI Percentage Point...               0.0029
#
#                                                                      27  \
# Unnamed: 0                                          2025-11-01 00:00:00
# Contribution to All groups CPI Percentage Point...               0.0157
# Contribution to All groups CPI Percentage Point...               0.0664
# Contribution to All groups CPI Percentage Point...               0.0124
# Contribution to All groups CPI Percentage Point...                0.002
#
#                                                                      28  \
# Unnamed: 0                                          2025-12-01 00:00:00
# Contribution to All groups CPI Percentage Point...               0.9639
# Contribution to All groups CPI Percentage Point...               0.0661
# Contribution to All groups CPI Percentage Point...                0.014
# Contribution to All groups CPI Percentage Point...               0.0028
#
#                                                                      29
# Unnamed: 0                                          2026-01-01 00:00:00
# Contribution to All groups CPI Percentage Point...                0.352
# Contribution to All groups CPI Percentage Point...               0.0873
# Contribution to All groups CPI Percentage Point...                0.003
# Contribution to All groups CPI Percentage Point...                0.002
#
# [5 rows x 30 columns]

# %%
CPT_Wide_resetIndex = CPT_Wide.reset_index()

# %%
CPT_Wide_resetIndex.head()
# Out:
#                                                index      0            1  \
# 0                                         Unnamed: 0   Unit  Series Type
# 1  Contribution to All groups CPI Percentage Poin...  % pts     Original
# 2  Contribution to All groups CPI Percentage Poin...  % pts     Original
# 3  Contribution to All groups CPI Percentage Poin...  % pts     Original
# 4  Contribution to All groups CPI Percentage Poin...  % pts     Original
#
#            2          3                 4                    5  \
# 0  Data Type  Frequency  Collection Month         Series Start
# 1    DERIVED      Month                 1  2024-05-01 00:00:00
# 2    DERIVED      Month                 1  2024-05-01 00:00:00
# 3    DERIVED      Month                 1  2024-05-01 00:00:00
# 4    DERIVED      Month                 1  2024-05-01 00:00:00
#
#                      6        7            8  ...                   20  \
# 0           Series End  No. Obs    Series ID  ...  2025-04-01 00:00:00
# 1  2026-01-01 00:00:00       21  A130393725R  ...               0.7401
# 2  2026-01-01 00:00:00       21  A130395482V  ...               0.0676
# 3  2026-01-01 00:00:00       21  A130391709C  ...              -0.0059
# 4  2026-01-01 00:00:00       21  A130393207R  ...              -0.0018
#
#                     21                   22                   23  \
# 0  2025-05-01 00:00:00  2025-06-01 00:00:00  2025-07-01 00:00:00
# 1               -0.493               0.1449                1.312
# 2               0.0198               0.0756                0.062
# 3              -0.0087              -0.0022               0.0109
# 4              -0.0028              -0.0021               0.0007
#
#                     24                   25                   26  \
# 0  2025-08-01 00:00:00  2025-09-01 00:00:00  2025-10-01 00:00:00
# 1              -0.0755               0.4484              -0.0074
# 2               0.0174              -0.0456               0.0258
# 3               0.0007              -0.0041               0.0013
# 4              -0.0003              -0.0005               0.0029
#
#                     27                   28                   29
# 0  2025-11-01 00:00:00  2025-12-01 00:00:00  2026-01-01 00:00:00
# 1               0.0157               0.9639                0.352
# 2               0.0664               0.0661               0.0873
# 3               0.0124                0.014                0.003
# 4                0.002               0.0028                0.002
#
# [5 rows x 31 columns]

# %%
#make first row as column name
CPT_Wide_resetIndex.columns = CPT_Wide_resetIndex.iloc[0]
CPT_DropFirstRow = CPT_Wide_resetIndex.drop(0, axis = 0)

# %%
#name the first column industry
firstColumnName = CPT_DropFirstRow.columns[0]
rename = 'Industry'
CPT_rename = CPT_DropFirstRow.rename(columns = {firstColumnName:rename})

# %%
#reset index
CPT_Wide_resetIndex = CPT_rename.reset_index(drop=True)

# %%
#extract the industry
CPT_Wide_resetIndex['Industry'] = CPT_Wide_resetIndex['Industry'].str.split(' ; ', expand=True)[1]

# %% [markdown]
# #### Step3 - extract the Month and Year information from the datetime (located in the first row originally), named as Month and Year.

# %%
CPT_Wide_resetIndex.columns[10:]
# Out:
# Index([2024-05-01 00:00:00, 2024-06-01 00:00:00, 2024-07-01 00:00:00,
#        2024-08-01 00:00:00, 2024-09-01 00:00:00, 2024-10-01 00:00:00,
#        2024-11-01 00:00:00, 2024-12-01 00:00:00, 2025-01-01 00:00:00,
#        2025-02-01 00:00:00, 2025-03-01 00:00:00, 2025-04-01 00:00:00,
#        2025-05-01 00:00:00, 2025-06-01 00:00:00, 2025-07-01 00:00:00,
#        2025-08-01 00:00:00, 2025-09-01 00:00:00, 2025-10-01 00:00:00,
#        2025-11-01 00:00:00, 2025-12-01 00:00:00, 2026-01-01 00:00:00],
#       dtype='object', name=0)

# %%
#Get the columns that are not CPT with dates
CPT_nonDateColumnNames = CPT_Wide_resetIndex.columns[:10].tolist()
CPT_nonDateColumnNames
# Out:
# ['Industry',
#  'Unit',
#  'Series Type',
#  'Data Type',
#  'Frequency',
#  'Collection Month',
#  'Series Start',
#  'Series End',
#  'No. Obs',
#  'Series ID']

# %%
#Melt the dataframe
CPT_MeltedDateTime = pd.melt(CPT_Wide_resetIndex, id_vars=CPT_nonDateColumnNames, var_name = 'DateTime', value_name = 'CPT_Changes')

# %%
CPT_MeltedDateTime.head()
# Out:
#                             Industry   Unit Series Type Data Type Frequency  \
# 0                     All groups CPI  % pts    Original   DERIVED     Month
# 1   Food and non-alcoholic beverages  % pts    Original   DERIVED     Month
# 2          Bread and cereal products  % pts    Original   DERIVED     Month
# 3                              Bread  % pts    Original   DERIVED     Month
# 4                 Cakes and biscuits  % pts    Original   DERIVED     Month
#
#   Collection Month Series Start Series End No. Obs    Series ID   DateTime  \
# 0                1   2024-05-01 2026-01-01      21  A130393725R 2024-05-01
# 1                1   2024-05-01 2026-01-01      21  A130395482V 2024-05-01
# 2                1   2024-05-01 2026-01-01      21  A130391709C 2024-05-01
# 3                1   2024-05-01 2026-01-01      21  A130393207R 2024-05-01
# 4                1   2024-05-01 2026-01-01      21  A130399329W 2024-05-01
#
#   CPT_Changes
# 0     -0.2307
# 1      0.0768
# 2      0.0015
# 3     -0.0013
# 4      0.0022

# %%
CPT_MeltedDateTime['Year'] = CPT_MeltedDateTime['DateTime'].dt.year

# %%
CPT_MeltedDateTime['Month'] = CPT_MeltedDateTime['DateTime'].dt.month

# %%
CPT_MeltedDateTime.head()
# Out:
#                             Industry   Unit Series Type Data Type Frequency  \
# 0                     All groups CPI  % pts    Original   DERIVED     Month
# 1   Food and non-alcoholic beverages  % pts    Original   DERIVED     Month
# 2          Bread and cereal products  % pts    Original   DERIVED     Month
# 3                              Bread  % pts    Original   DERIVED     Month
# 4                 Cakes and biscuits  % pts    Original   DERIVED     Month
#
#   Collection Month Series Start Series End No. Obs    Series ID   DateTime  \
# 0                1   2024-05-01 2026-01-01      21  A130393725R 2024-05-01
# 1                1   2024-05-01 2026-01-01      21  A130395482V 2024-05-01
# 2                1   2024-05-01 2026-01-01      21  A130391709C 2024-05-01
# 3                1   2024-05-01 2026-01-01      21  A130393207R 2024-05-01
# 4                1   2024-05-01 2026-01-01      21  A130399329W 2024-05-01
#
#   CPT_Changes  Year  Month
# 0     -0.2307  2024      5
# 1      0.0768  2024      5
# 2      0.0015  2024      5
# 3     -0.0013  2024      5
# 4      0.0022  2024      5

# %% [markdown]
# #### Step4 - deleted the columns/information that is not neceessary, for example colleciton month, series start, etc.

# %%
CPT = CPT_MeltedDateTime.copy()

# %%
CPT['No. Obs'].unique()
# Out:
# array([21], dtype=object)

# %% [markdown]
# Remove Unit, Series Type, Data Type, Frequency, Collection Month, No.Obs, because there is only one value in these columns

# %%
dropedColumns = ['Unit', 'Series Type', 'Data Type', 'Frequency', 'Collection Month', 'No. Obs']

# %%
CPT_DropedColumns = CPT.drop(columns = dropedColumns, axis = 1)

# %% [markdown]
# Also dropped Series Start, Series end and Series ID cause its not relavant to CPT changes. Dropped DateTime Cause we already have Year and Month

# %%
dropedColumns = ['Series Start', 'Series End', 'DateTime', 'Series ID']

# %%
CPT_DropedDates = CPT_DropedColumns.drop(columns = dropedColumns, axis = 1)

# %%
CPT_DropedDates.shape
# Out:
# (2772, 4)

# %% [markdown]
# ### Employment to population Ration

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
EmployPopulationRatial_Original
# Out:
#                                                              Employment-to-population ratio
# NaN                                                Trend (%)        Seasonally adjusted (%)
# Jan-16                                             61.4                                61.3
# Feb-16                                             61.3                                61.3
# Mar-16                                             61.3                                61.3
# Apr-16                                             61.3                                61.2
# ...                                                                                     ...
# Nov-25                                             63.9                                63.8
# Dec-25                                             63.9                                64.0
# Jan-26                                             64.0                                63.9
# Large month-to-month changes occurred during th... NaN                                  NaN
# Source: Australian Bureau of Statistics, Labour... NaN                                  NaN
#
# [124 rows x 1 columns]

# %%
EmployPopulationRatial = EmployPopulationRatial_Original.copy()

# %% [markdown]
# Observation:\
# The size of the data set is 124X1. The only column is named Employment-to-population ratio. Under the column there are three sub-columns. The first column is datetime, and the rest are the numerical data. The last two rows are not the value of the datasets.

# %% [markdown]
# #### Data processing plan

# %% [markdown]
# Step1 - reset index and the column names.\
# Step2 - remove the last two rows.\
# Step3 - extract month and year.

# %% [markdown]
# #### Step1 - reset index and the column names.

# %%
EmployPopulationRatial_ResetIndex = EmployPopulationRatial.reset_index()

# %%
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetIndex.copy()
EmployPopulationRatial_ResetColumnName.columns = EmployPopulationRatial_ResetColumnName.iloc[0].tolist()
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetColumnName.iloc[1:]

# %%
OriginalColumnNames = EmployPopulationRatial_ResetColumnName.columns
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetColumnName.rename(columns = {OriginalColumnNames[0]:'Date', OriginalColumnNames[1]:'Employment_Population_Ratio', OriginalColumnNames[2]:'Ratio_SeasonallyAdjusted'})

# %%
EmployPopulationRatial_ResetColumnName.head()
# Out:
#      Date Employment_Population_Ratio Ratio_SeasonallyAdjusted
# 1  Jan-16                        61.4                     61.3
# 2  Feb-16                        61.3                     61.3
# 3  Mar-16                        61.3                     61.3
# 4  Apr-16                        61.3                     61.2
# 5  May-16                        61.2                     61.1

# %% [markdown]
# #### Step2 - remove the last two rows.

# %%
EmployPopulationRatial_RemovedRows = EmployPopulationRatial_ResetColumnName.iloc[:121] 
EmployPopulationRatial_RemovedRows
# Out:
#        Date Employment_Population_Ratio Ratio_SeasonallyAdjusted
# 1    Jan-16                        61.4                     61.3
# 2    Feb-16                        61.3                     61.3
# 3    Mar-16                        61.3                     61.3
# 4    Apr-16                        61.3                     61.2
# 5    May-16                        61.2                     61.1
# ..      ...                         ...                      ...
# 117  Sep-25                        64.0                     63.9
# 118  Oct-25                        63.9                     64.0
# 119  Nov-25                        63.9                     63.8
# 120  Dec-25                        63.9                     64.0
# 121  Jan-26                        64.0                     63.9
#
# [121 rows x 3 columns]

# %% [markdown]
# #### Step3 - extract month and year.

# %%
EmployPopulationRatial_ExtractMonthYear = EmployPopulationRatial_RemovedRows.copy()

# %%
MonthYear = EmployPopulationRatial_ExtractMonthYear['Date'].str.split('-', expand=True)

# %%
MonthYear.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
EmployPopulationRatial_ExtractMonthYear['Month_Name'] = MonthYear[0]
EmployPopulationRatial_ExtractMonthYear['Year'] = MonthYear[1]

# %%
EmployPopulationRatial_ExtractMonthYear['Month'] = pd.to_datetime(EmployPopulationRatial_ExtractMonthYear['Month_Name'], format='%b').dt.month

# %%
# drop Date, Month_Name
EmployPopulationRatial = EmployPopulationRatial_ExtractMonthYear.drop(columns = ['Date', 'Month_Name'])

# %%
EmployPopulationRatial.head()
# Out:
#   Employment_Population_Ratio Ratio_SeasonallyAdjusted Year  Month
# 1                        61.4                     61.3   16      1
# 2                        61.3                     61.3   16      2
# 3                        61.3                     61.3   16      3
# 4                        61.3                     61.2   16      4
# 5                        61.2                     61.1   16      5
